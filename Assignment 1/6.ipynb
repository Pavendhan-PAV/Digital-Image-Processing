# %%
import numpy as np 
import cv2
from matplotlib import pyplot as plt 

img = cv2.imread("pout-dark.jpg",0)
equ = cv2.equalizeHist(img)
result = np.hstack((img,equ))
#cv2.imwrite('6_result.png',result)
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.show()
